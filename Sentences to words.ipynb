# %%
import json
with open('/content/8470.json', encoding='utf-8') as f:
    datastore = json.load(f)

sentences = []

for item in datastore:
    sentences.append(item['content'])

# %%
print(sentences[0])
# Out:
# এই মূহুর্তে ভারত পাকিস্তান নিয়ে কোন কথা শুনতে চাইনা যদি পারেন মায়ানমারের দুখি মানুষ গুলাকে নিয়ে বেশী বেশী লিখেন

# %%
print(sentences[0].split())
# Out:
# ['এই', 'মূহুর্তে', 'ভারত', 'পাকিস্তান', 'নিয়ে', 'কোন', 'কথা', 'শুনতে', 'চাইনা', 'যদি', 'পারেন', 'মায়ানমারের', 'দুখি', 'মানুষ', 'গুলাকে', 'নিয়ে', 'বেশী', 'বেশী', 'লিখেন']

# %%
words=[]

# %%
for items in sentences:
  print(items.split())
  words.append(items.split())
# Out:
# Streaming output truncated to the last 5000 lines.
# ['তাকে', 'মেনশন', 'করুন,', 'যে', 'ফ্রেন্ড', 'বাসর', 'রাতে', 'এভাবে', 'খাট', 'ভেঙে', 'ফেলবে']
# ['নিজেদের', 'ঈমান', 'আমল', 'নিয়ে', 'বেঁচে', 'থাকেন', 'তা', 'মজবুত', 'করতে', 'ইসলাম', 'সম্পর্কে', 'ভালো', 'করে', 'জানেন', 'সাফা', 'কবির', 'তার', 'মত', 'প্রকাশ', 'করেছে', 'তার', 'নিজস্ব', 'চেতনা', 'বিশ্বাস', 'থাকতেই', 'পারে', 'তাই', 'বলে', 'এই', 'না', 'যে', 'ইসলাম', 'তাকে', 'গালি', 'মৃত্যু', 'হুমকি', 'দিতে', 'বলেছে', 'দয়া', 'করে', 'বলদা', 'বাঙ্গালী', 'তকমাটা', 'ইসলামের', 'মত', 'পবিত্র', 'ধর্মের', 'সাথে', 'মিশিয়ে', 'নষ্টামি', 'করবেন', 'না', 'যার', 'বিশ্বাস', 'তা', 'নিয়ে', 'তাকে', 'বেঁচে', 'থাকতে', 'দেন']
# ['মার', 'রাজু', 'মার,', 'এই', 'শয়তান', 'তোর', 'বাবাকে', 'বিশ', 'বছর', 'আগে', 'ঠান্ডা', 'পানিতে', 'গোসল', 'করিয়েছে।']
# ['সালা', 'মুরগিচোর']
# ['জায়েদ', 'খান', 'নায়ক', 'না', 'কি', 'ভাই', 'আমি', 'তো', 'জানতাম', 'না', 'ওর', 'ছবি', 'আছে', 'নাকি', 'ও', 'আবার', 'নায়ক', 'হয়েছে', 'কবে', 'ছাগল']
# ...

# %%
all_words=[]

# %%
print(words[8469][0])
# Out:
# আমি

# %%
for i in range(len(words)):
  for j in range(len(words[i])):
    all_words.append(words[i][j])

# %%
print(len(all_words))
# Out:
# 260716

# %%
pip install xlsxwriter
# Out:
# ...
#      |████████████████████████████████| 148 kB 5.0 MB/s
# ...

# %%
# import xlsxwriter module
import xlsxwriter
 
workbook = xlsxwriter.Workbook('/content/8470.xlsx')
worksheet = workbook.add_worksheet()
 
# Start from the first cell.
# Rows and columns are zero indexed.
row = 0
column = 0

 
# iterating through content list
for item in all_words :
 
    # write operation perform
    worksheet.write(row, column, item)
 
    # incrementing the value of row by one
    # with each iterations.
    row += 1
     
workbook.close()

# %%
print(all_words)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
